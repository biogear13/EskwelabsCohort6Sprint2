# %%
# importing the libraries for data processing
import numpy as np 
import pandas as pd 

#matplotlib for visualizations
import matplotlib.pyplot as plt

# %%
# read and process the charts dataset
charts_df = pd.read_csv('data/spotify_daily_charts.csv')
#transform date column into a datetime column
charts_df['date'] = pd.to_datetime(charts_df['date'])
charts_df.head()
# Out:
#         date  position                track_id            track_name  \
# 0 2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 1 2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2 2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw                Closer
# 3 2017-01-01         4  2rizacJSyD9S1IQUxUxnsK           All We Know
# 4 2017-01-01         5  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know
#
#              artist  streams
# 0        Bruno Mars   185236
# 1      James Arthur   180552
# 2  The Chainsmokers   158720
# 3  The Chainsmokers   130874
# 4          Maroon 5   129656

# %%
# read and process the tracks dataset
tracks_df = pd.read_csv('data/spotify_daily_charts_tracks.csv')
tracks_df.head()
# Out:
#                  track_id            track_name               artist_id  \
# 0  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor  0du5cEVh5yTK9QJze8zA0C
# 1  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go  4IWBUUAFIplrNtaOHcJPRM
# 2  7BKLCZ1jbUBVqRi2FVlTVw                Closer  69GGBxA162lTqCwzJG5jLp
# 3  2rizacJSyD9S1IQUxUxnsK           All We Know  69GGBxA162lTqCwzJG5jLp
# 4  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know  04gDigrS5kc9YWfZHwBETP
#
#         artist_name                album_id  duration release_date  \
# 0        Bruno Mars  4PgleR09JVnm3zY1fW3XBA    261240   2016-11-17
# 1      James Arthur  7oiJYvEJHsmYtrgviAVIBD    211466   2016-10-28
# 2  The Chainsmokers  0rSLgV8p5FzfnqlEk4GzxE    244960   2016-07-29
# 3  The Chainsmokers  0xmaV6EtJ4M3ebZUPRnhyb    194080   2016-09-29
# 4          Maroon 5  0fvTn3WXF39kQs9i3bnNpP    214480   2016-10-11
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          76         0.578   0.574    2    -6.209     1       0.0454
# 1          88         0.358   0.557   10    -7.398     1       0.0590
# 2          87         0.748   0.524    8    -5.599     1       0.0338
# 3          71         0.662   0.586    0    -8.821     1       0.0307
# 4           1         0.783   0.623    7    -6.126     1       0.0800
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0         0.196           0.00000    0.0830    0.301  174.152
# 1         0.695           0.00000    0.0902    0.494   85.043
# 2         0.414           0.00000    0.1110    0.661   95.010
# 3         0.097           0.00272    0.1150    0.296   90.000
# 4         0.338           0.00000    0.0975    0.447  100.048

# %%
#merge the charts and tracks dataset
df = charts_df.merge(tracks_df, on='track_id', how='left')
#
df = df.drop(columns='track_name_y')
df = df.rename(columns={'track_name_x':'track_name'})
df
# Out:
#              date  position                track_id  \
# 0      2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP
# 1      2017-01-01         2  5uCax9HTNlzGybIStD3vDh
# 2      2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw
# 3      2017-01-01         4  2rizacJSyD9S1IQUxUxnsK
# 4      2017-01-01         5  5MFzQMkrl1FOOng9tq6R9r
# ...           ...       ...                     ...
# 294595 2021-01-15       196  6lanRgr6wXibZr8KgzXxBl
# 294596 2021-01-15       197  2FVpOsjT1iquZ3SpCjZ9Ne
# 294597 2021-01-15       198  0rbKrBvZUYY9GN9l057BuY
# 294598 2021-01-15       199  4Dq2FjRkOTHcssggMdYK8J
# 294599 2021-01-15       200  0gcjc7Vt5xtcfmJgf6g2IO
#
#                          track_name            artist  streams  \
# 0              Versace on the Floor        Bruno Mars   185236
# 1              Say You Won't Let Go      James Arthur   180552
# 2                            Closer  The Chainsmokers   158720
# 3                       All We Know  The Chainsmokers   130874
# 4                  Don't Wanna Know          Maroon 5   129656
# ...                             ...               ...      ...
# 294595             A Thousand Years   Christina Perri    28709
# 294596                    Telepathy               BTS    28689
# 294597            always, i'll care     Jeremy Zucker    28649
# 294598                  MY TREASURE          TREASURE    28527
# 294599  When You Say Nothing At All     Ronan Keating    28334
#
#                      artist_id       artist_name                album_id  \
# 0       0du5cEVh5yTK9QJze8zA0C        Bruno Mars  4PgleR09JVnm3zY1fW3XBA
# 1       4IWBUUAFIplrNtaOHcJPRM      James Arthur  7oiJYvEJHsmYtrgviAVIBD
# 2       69GGBxA162lTqCwzJG5jLp  The Chainsmokers  0rSLgV8p5FzfnqlEk4GzxE
# 3       69GGBxA162lTqCwzJG5jLp  The Chainsmokers  0xmaV6EtJ4M3ebZUPRnhyb
# 4       04gDigrS5kc9YWfZHwBETP          Maroon 5  0fvTn3WXF39kQs9i3bnNpP
# ...                        ...               ...                     ...
# 294595  7H55rcKCfwqkyDFH9wpKM6   Christina Perri  15yvc643iYfQtb6zh9NEJo
# 294596  3Nrfpe0tUJi4K4DXYWgMUX               BTS  2qehskW9lYGWfYb0xPZkrS
# 294597  3gIRvgZssIb9aiirIg0nI3     Jeremy Zucker  5mkf4N44kdEwYgaOk3hRLF
# 294598  3KonOYiLsU53m4yT7gNotP          TREASURE  5tQDFmW8QrZdTsICpLQBTL
# 294599  3nlHsNqwCSvT988ZfSW1Yh     Ronan Keating  3T9Imnmd2Amt5lyDMqlFq9
#
#         duration  ... energy  key  loudness  mode  speechiness  acousticness  \
# 0         261240  ...  0.574    2    -6.209     1       0.0454       0.19600
# 1         211466  ...  0.557   10    -7.398     1       0.0590       0.69500
# 2         244960  ...  0.524    8    -5.599     1       0.0338       0.41400
# 3         194080  ...  0.586    0    -8.821     1       0.0307       0.09700
# 4         214480  ...  0.623    7    -6.126     1       0.0800       0.33800
# ...          ...  ...    ...  ...       ...   ...          ...           ...
# 294595    285120  ...  0.407   10    -7.445     1       0.0267       0.30900
# 294596    202313  ...  0.669    5    -4.333     0       0.0428       0.00782
# 294597    146160  ...  0.221    6   -12.623     1       0.0560       0.89700
# 294598    195982  ...  0.785    6    -4.564     1       0.0780       0.11100
# 294599    256826  ...  0.448    7   -10.665     1       0.0251       0.16100
#
#         instrumentalness  liveness  valence    tempo
# 0               0.000000    0.0830    0.301  174.152
# 1               0.000000    0.0902    0.494   85.043
# 2               0.000000    0.1110    0.661   95.010
# 3               0.002720    0.1150    0.296   90.000
# 4               0.000000    0.0975    0.447  100.048
# ...                  ...       ...      ...      ...
# 294595          0.000961    0.1100    0.161  139.028
# 294596          0.000000    0.1230    0.570  104.994
# 294597          0.000026    0.1100    0.677  105.165
# 294598          0.000000    0.1410    0.526  107.931
# 294599          0.000001    0.0811    0.418  173.885
#
# [294600 rows x 23 columns]

# %%
artist = df.groupby(['artist'])['position'].min().reset_index()

# %%
artist = artist[artist['position']>150].sort_values('position')
artist.to_csv('artist1150.csv')
